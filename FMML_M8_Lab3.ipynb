# %% [markdown]
# <a href="https://colab.research.google.com/github/Sairamya07/Fmml-labs/blob/main/FMML_M8_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-21 07:43:09--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   107MB/s    in 0.6s
#
# 2025-03-21 07:43:11 (107 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22234  1509.04681v2  This paper addresses the problem of scalable o...  stat
# 22074   1410.2653v1  Distributed learning of probabilistic models f...  stat
# 3577   1712.09713v1  The difficulty of multi-class classification g...  stat
# 3280    1409.3660v4  Subset selection from massive data with noised...    cs
# 10262   1005.3579v1  We consider the problem of learning a structur...  stat
# ...             ...                                                ...   ...
# 7629   1802.05693v1  Many platforms are characterized by the fact t...    cs
# 29007  1708.02165v1  Current object segmentation algorithms are bas...    cs
# 6117   1607.06996v5  Sparse support vector machine (SVM) is a popul...  stat
# 2723   1708.08227v3  Generating molecules with desired chemical pro...  stat
# 3398   1611.05209v1  Variational autoencoders (VAEs), that are buil...  stat
#
#                                                    title  year  \
# 22234  Large-Scale Optimization Algorithms for Sparse...  2015
# 22074  Distributed Estimation, Information Loss and E...  2014
# 3577   Extrapolating Expected Accuracies for Large Mu...  2017
# 3280   10,000+ Times Accelerated Robust Subset Select...  2014
# 10262  Graph-Structured Multi-task Regression and an ...  2010
# ...                                                  ...   ...
# 7629         Bandit Learning with Positive Externalities  2018
# 29007  Learning to segment on tiny datasets: a new sh...  2017
# 6117   Scaling Up Sparse Support Vector Machines by S...  2016
# 2723   ChemGAN challenge for drug discovery: can AI r...  2017
# 3398   Deep Variational Inference Without Pixel-Wise ...  2016
#
#                                                 keywords
# 22234  [addresses, optimization, regularized, conditi...
# 22074  [distributed, probabilistic, repositories, com...
# 3577   [difficulty, classification, generally, increa...
# 3280   [selection, information, increasingly, applica...
# 10262  [structured, regression, responses, correlated...
# ...                                                  ...
# 7629   [platforms, characterized, preferences, satisf...
# 29007  [segmentation, algorithms, hypothesis, automat...
# 6117   [classification, technique, simultaneously, in...
# 2723   [generating, molecules, properties, important,...
# 3398   [variational, autoencoders, generative, improv...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22234    [addresses, optimization, regularized, conditi...
# 22074    [distributed, probabilistic, repositories, com...
# 3577     [difficulty, classification, generally, increa...
# 3280     [selection, information, increasingly, applica...
# 10262    [structured, regression, responses, correlated...
#                                ...
# 39864    [developed, comicolorization, automatic, color...
# 12631    [probabilistic, graphical, understand, depende...
# 24995    [addresses, unsupervised, discovery, localizat...
# 6260     [extrapolate, previously, knowledge, assumptio...
# 17464    [attention, reinforcement, optimizing, classic...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8782 words.
# Out of those 4555 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="721a21ba-16b6-445b-bf08-a8de233eba06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("721a21ba-16b6-445b-bf08-a8de233eba06")) {                    Plotly.newPlot(                        "721a21ba-16b6-445b-bf08-a8de233eba06",                        [{"x":["distributions","influenced","synthetic","improvement","convergence","algorithms","achieving","regularized","efficient","constraints","generalize","coordinate","dimensional","addresses","optimization","estimation","variables","conditioning","computation","graphical","procedure","importantly","efficiently","conditional","increasingly","exponential","efficiency","communication","calculates","arbitrary","empirical","information","misspecification","heterogeneous","repositories","important","convexity","properties","distribution","combinations","probabilistic","connection","outperforms","underlying","distributed","combination","partitions","significantly","represents","estimates","practical","divergence","likelihood","frameworks","approximation","framework","statistical","identically","independently","estimated","accuracies","generally","increases","difficulty","assumptions","demonstrate","extrapolating","classification","recognition","application","classifier","increased","functions","population","preventing","objective","equivalent","sensitive","representation","accelerated","selection","challenging","computational","observation","extensive","benchmark","robustness","specifically","applications","experiments","theoretically","dominating","scalability","structures","regression","structure","programming","encourage","introduce","dependent","formulations","exploiting","experimental","optimizing","responses","correlated","superiority","structured","consistency","quadratic","synergistic","synthesize","perceptual","evaluated","examiners","synthesis","protocols","reconstructed","approaches","adversarial","generative","semantically","optimized","performance","discriminative","reconstructing","preserving","realistic","discrepancy","reconstruction","meaningful","characteristics","corresponding","reconstruct","different","normalization","structural","directional","directions","reservoirs","processing","criterion","distances","carefully","validated","typically","particles","introducing","depending","continuous","dependence","relational","metropolis","denoising","algorithm","propagation","particular","inference","distortion","theoretical","preservation","conditions","projections","projected","projection","preserved","multiclass","inspecting","unavailable","complexity","furthermore","incoherent","representative","limitations","electronic","exploration","preferred","selectively","summarization","recommendation","approximated","previously","partially","assumption","introduced","suppression","basically","evaluation","comparison","detection","implement","binarization","segmentation","mammograms","comparative","techniques","conservation","coefficients","explaining","thousands"],"y":[109,9,129,146,135,635,76,30,383,144,52,21,195,40,307,211,147,13,145,57,122,29,130,101,66,50,160,46,7,93,154,720,1,33,4,339,8,228,212,42,155,46,255,111,88,119,14,264,39,74,134,27,71,31,133,540,174,2,36,58,19,75,57,45,59,549,0,465,391,243,135,45,207,45,12,143,45,62,361,10,155,279,293,56,162,218,96,174,433,607,35,3,44,113,117,334,123,18,335,83,16,76,378,59,25,42,38,104,70,34,0,15,20,128,2,34,14,22,421,91,105,43,47,883,86,13,55,57,9,101,46,89,124,29,746,26,66,20,39,4,307,49,36,26,37,115,8,54,40,99,24,27,7,37,784,72,246,200,21,154,10,125,19,20,43,9,8,0,5,255,167,1,44,55,18,61,5,9,28,27,17,103,58,77,126,7,7,255,133,340,64,6,176,5,35,381,4,43,27,28],"type":"bar"},{"x":["distributions","influenced","synthetic","improv ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4555,), (4555, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.815

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>and</span> <span style=''>accurate</span> <span style='background-color:rgba(0, 255, 0, 0.6785714285714286);'>sentiment</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>using</span> <span style=''>an</span> <span style=''>enhanced</span> <span style=''>Naive</span> <span style=''>Bayes</span> <span style=''>model</span> <br/><br/><span style=''>We</span> <span style=''>have</span> <span style=''>explored</span> <span style='background-color:rgba(0, 255, 0, 0.30992098331870066);'>different</span> <span style=''>methods</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.37254901960784303);'>improving</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Naive</span> <span style=''>Bayes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.6785714285714286);'>sentiment</span> <span style=''>analysis</span> <span style=''>We</span> <span style=''>observed</span> <span style=''>that</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>methods</span> <span style=''>like</span> <span style=''>negation</span> <span style=''>handling</span> <span style=''>word</span> <span style=''>n</span> <span style=''>grams</span> <span style=''>and</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>by</span> <span style=''>mutual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>results</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.32480818414322243);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.3035714285714286);'>improvement</span> <span style=''>in</span> <span style=''>accuracy</span> <span style=''>This</span> <span style=''>implies</span> <span style=''>that</span> <span style=''>a</span> <span style=''>highly</span> <span style=''>accurate</span> <span style=''>and</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.6785714285714286);'>sentiment</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>can</span> <span style=''>be</span> <span style=''>built</span> <span style=''>using</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>Naive</span> <span style=''>Bayes</span> <span style=''>model</span> <span style=''>that</span> <span style=''>has</span> <span style=''>linear</span> <span style=''>training</span> <span style=''>and</span> <span style=''>testing</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>complexities</span> <span style=''>We</span> <span style=''>achieved</span> <span style=''>an</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>8880</span> <span style=''>on</span> <span style=''>the</span> <span style=''>popular</span> <span style=''>IMDB</span> <span style=''>movie</span> <span style=''>reviews</span> <span style=''>dataset</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style=''>Reduced</span> <span style=''>Rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>reduced</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>for</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>An</span> <span style=''>additive</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>for</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>a</span> <span style=''>q</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>response</span> <span style=''>with</span> <span style=''>a</span> <span style=''>shared</span> <span style=''>p</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>variable</span> <span style=''>To</span> <span style=''>control</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>we</span> <span style=''>employ</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>form</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Ky</span> <span style=''>Fan</span> <span style=''>or</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>that</span> <span style=''>have</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Backfitting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>justified</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>form</span> <span style=''>of</span> <span style=''>the</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style=''>subdifferential</span> <span style=''>Oracle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inequalities</span> <span style=''>on</span> <span style=''>excess</span> <span style=''>risk</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>that</span> <span style=''>exhibit</span> <span style=''>the</span> <span style=''>scaling</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>in</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>setting</span> <span style=''>The</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(0, 2 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.30630630630630623);'>Regularization</span> <span style=''>for</span> <span style=''>Weight</span> <span style=''>Matrices</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.38764044943820225);'>distributions</span> <span style=''>over</span> <span style=''>weight</span> <span style=''>vectors</span> <span style=''>such</span> <span style=''>as</span> <span style=''>AROW</span> <span style=''>were</span> <span style=''>recently</span> <span style=''>shown</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirically</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>at</span> <span style=''>various</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>strong</span> <span style='background-color:rgba(255, 0, 0, 0.3109619686800895);'>theoretical</span> <span style=''>guaranties</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Extending</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>matrix</span> <span style=''>models</span> <span style=''>pose</span> <span style='background-color:rgba(0, 255, 0, 0.31550802139037426);'>challenges</span> <span style=''>since</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6261682242990655);'>covariance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>scales</span> <span style=''>as</span> <span style=''>n4</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3689320388349514);'>dimension</span> <span style=''>n</span> <span style=''>of</span> <span style=''>the</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>n</span> <span style=''>tends</span> <span style=''>to</span> <span style=''>be</span> <span style=''>large</span> <span style=''>in</span> <span style=''>real</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>analyze</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.40384615384615385);'>experiment</span> <span style=''>with</span> <span style=''>two</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>matrix</span> <span style=''>models</span> <span style=''>Our</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maintains</span> <span style=''>a</span> <span style=''>diagonal</span> <span style='background-color:rgba(255, 0, 0, 0.6261682242990655);'>covariance</span> <span style=''>over</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>and</span> <span style=''>can</span> <span style=''>handle</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.6261682242990655);'>covariance</span> <span style=''>matrices</span> <span style=''>The</span> <span style=''>second</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Maximum</span> <span style=''>Margin</span> <span style=''>Interval</span> <span style=''>Trees</span> <br/><br/><span style=''>Learning</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>function</span> <span style=''>using</span> <span style=''>censored</span> <span style=''>or</span> <span style=''>interval</span> <span style=''>valued</span> <span style=''>output</span> <span style=''>data</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>fields</span> <span style=''>such</span> <span style=''>as</span> <span style=''>genomics</span> <span style=''>and</span> <span style=''>medicine</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>real</span> <span style=''>valued</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>function</span> <span style=''>and</span> <span style=''>the</span> <span style=''>training</span> <span style=''>output</span> <span style=''>labels</span> <span style=''>indicate</span> <span style=''>an</span> <span style=''>interval</span> <span style=''>of</span> <span style=''>possible</span> <span style=''>values</span> <span style=''>Whereas</span> <span style=''>most</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>this</span> <span style=''>task</span> <span style=''>are</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>tree</span> <span style=''>models</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>tree</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>a</span> <span style=''>margin</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>and</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>in</span> <span style=''>log</span> <span style=''>linear</span> <span style=''>time</span> <span style=''>We</span> <span style=''>show</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style=''>that</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>achieves</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>speed</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>accuracy</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>of</span> <span style=''>several</span> <span style=''>data</span> <span style=''>sets</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13451957295373665)
# 	knowledge (0.12419928825622775)
# 	representation (0.1284697508896797)
# 	processing (0.1092526690391459)
# 	architecture (0.09074733096085409)
# 	information (0.25622775800711745)
# 	detection (0.12099644128113879)
# 	different (0.26548042704626335)
# 	recognition (0.1391459074733096)
# 	convolutional (0.1480427046263345)
#
# Some Statistics words are:
# 	statistical (0.1492462311557789)
# 	variational (0.10452261306532663)
# 	estimation (0.16532663316582916)
# 	stochastic (0.1371859296482412)
# 	theoretical (0.14723618090452262)
# 	distribution (0.18743718592964825)
# 	algorithm (0.3914572864321608)
# 	dimensional (0.19246231155778895)
# 	inference (0.2)
# 	regression (0.18190954773869347)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1220fd09-86d3-464c-9d3c-041f7869dff1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1220fd09-86d3-464c-9d3c-041f7869dff1")) {                    Plotly.newPlot(                        "1220fd09-86d3-464c-9d3c-041f7869dff1",                        [{"x":["distributions","influenced","synthetic","improvement","convergence","algorithms","achieving","regularized","efficient","constraints","generalize","coordinate","dimensional","addresses","optimization","estimation","variables","conditioning","computation","graphical","procedure","importantly","efficiently","conditional","increasingly","exponential","efficiency","communication","calculates","arbitrary","empirical","information","misspecification","heterogeneous","repositories","important","convexity","properties","distribution","combinations","probabilistic","connection","outperforms","underlying","distributed","combination","partitions","significantly","represents","estimates","practical","divergence","likelihood","frameworks","approximation","framework","statistical","identically","independently","estimated","accuracies","generally","increases","difficulty","assumptions","demonstrate","extrapolating","classification","recognition","application","classifier","increased","functions","population","preventing","objective","equivalent","sensitive","representation","accelerated","selection","challenging","computational","observation","extensive","benchmark","robustness","specifically","applications","experiments","theoretically","dominating","scalability","structures","regression","structure","programming","encourage","introduce","dependent","formulations","exploiting","experimental","optimizing","responses","correlated","superiority","structured","consistency","quadratic","synergistic","synthesize","perceptual","evaluated","examiners","synthesis","protocols","reconstructed","approaches","adversarial","generative","semantically","optimized","performance","discriminative","reconstructing","preserving","realistic","discrepancy","reconstruction","meaningful","characteristics","corresponding","reconstruct","different","normalization","structural","directional","directions","reservoirs","processing","criterion","distances","carefully","validated","typically","particles","introducing","depending","continuous","dependence","relational","metropolis","denoising","algorithm","propagation","particular","inference","distortion","theoretical","preservation","conditions","projections","projected","projection","preserved","multiclass","inspecting","unavailable","complexity","furthermore","incoherent","representative","limitations","electronic","exploration","preferred","selectively","summarization","recommendation","approximated","previously","partially","assumption","introduced","suppression","basically","evaluation","comparison","detection","implement","binarization","segmentation","mammograms","comparative","techniques","conservation","coefficients","explaining","thousands","explanation","incorporate","interpret","analysing","strikingly","interactions","alternatives","predictive","interestingly","representing","motivations","difficult","explained","inferences","sufficient","coefficient","traditional","automatically","optimisation","populations","attractor","evolution","experiment","magnitude","attracting","combining","classifiers","transformed","algebraic","embedding","constructing","dimensionality","necessary","capabilities","guaranteed","generalizability","therefore","confounding","filtering","confounders","architecture","effectively","imperfect","predictions","confounder","extending","correcting","inappropriately","prediction","including","permitted","successes","influence","develop ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	extrapolating
# 	synergistic
# 	inspecting
# 	confounders
# 	confounder
# 	multiparametric
# 	comprehensible
# 	robustification
# 	astrophysics
# 	tsybakovs
# 	reparameterization
# 	inversely
# 	proportionally
# 	trivially
# 	certificate
# 	infectious
# 	invertible
# 	straggler
# 	stragglers
# 	tempering
# Some words which never appear in Statistics papers:
# 	dominating
# 	examiners
# 	reservoirs
# 	suppression
# 	mammograms
# 	attracting
# 	overwhelmingly
# 	triangulation
# 	concatenation
# 	sentiments
# 	bachelors
# 	annotating
# 	afterwards
# 	localglobal
# 	inspiring
# 	retinopathy
# 	incredible
# 	controllers
# 	reasoners
# 	articulated

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.062318174858368e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
